# %% [markdown]
# NYC- Fare Prediction -- This notebook will be used to store data in a Azure cosmos DB for NOSQL service

# %%
import json
import pandas as pd
import numpy as np
import os
import pathlib
import re

#-------------- AZURE MODULES
from azure.cosmos import CosmosClient

# %%
curr_path = pathlib.Path.cwd()
data_path = str(curr_path.parent.parent.parent.parent) + "/data_scientist_challenge_sp/datasets/dataset-test-general.json"

# %%
with open(data_path, 'r') as f:
    data = json.load(f)


df = pd.DataFrame.from_dict(data,orient="columns")
df.drop("DOLocationID", axis=1,inplace=True)
df.reset_index(inplace=True,drop=True)


#include ID in database...

id_series = pd.Series(np.arange(1,df.shape[0] + 1,dtype=int),name="ItemID")

df = pd.concat([id_series,df],axis=1)

# %%
df
# Out:
#         ItemID  tpep_pickup_month  tpep_pickup_day  tpep_pickup_dow  \
# 0            1                  1                1                7
# 1            2                  1                1                7
# 2            3                  1                1                7
# 3            4                  1                1                7
# 4            5                  1                1                7
# ...        ...                ...              ...              ...
# 479065  479066                  2               27                1
# 479066  479067                  2               27                1
# 479067  479068                  2               27                1
# 479068  479069                  2               27                1
# 479069  479070                  2               27                1
#
#         tpep_pickup_hour  passenger_count  PULocationID  extra  mta_tax  \
# 0                      0              1.0           229    2.5      0.5
# ...

# %%
df.group

# %% [markdown]
# # Connect to Azure Cosmos DB for NOSQL

# %%
os.environ["COSMOSDB_ACCNT_URI"]
URL = os.environ['COSMOSDB_ACCNT_URI']
KEY = os.environ['COSMOSDB_ACCNT_key']
client = CosmosClient(URL, credential=KEY)

azure_cosmos_db = client.get_database_client("db-1")
container = azure_cosmos_db.get_container_client("NYCTestSetSP")

# %%
for i in range(df.shape[0]):
    row = df.iloc[i,:].to_dict()
    row["id"] = str(i + 1)
    container.create_item(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 4
#       2 row = df.iloc[i,:].to_dict()
#       3 row["id"] = str(i + 1)
# ----> 4 container.create_item(row)
#
# File c:\Users\kevin\miniconda3\envs\nyc-fare-prediction\lib\site-packages\azure\core\tracing\decorator.py:94, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      92 span_impl_type = settings.tracing_implementation()
#      93 if span_impl_type is None:
# ---> 94     return func(*args, **kwargs)
#      96 # Merge span is parameter is set, but only if no explicit parent are passed
#      97 if merge_span and not passed_in_parent:
#
# ...

# %%
res = []
mi_string = list("abcd")
n = len(mi_string)
def find_anagram(arr_string,l,r):
    global res
    if r == n-1:
        return ["".join(arr_string)]

    for r in range(l,n):
        #switch 
        arr_string[l],arr_string[r] = arr_string[r],arr_string[l]
        res = res + find_anagram(arr_string,l+1,r)
    return res

#l 3 2 1
#abcd , abdc , acbd, acdb, adbc, adcb, 

#permutations of bcd -> bcd, bdc, cbd, cdb, dbc, dcb
#permutations of abcd -> abcd, abdc, acbd, acdb, adbc, adcb

# %%
dic1 = {
    "a" : 1,
    "b" : 1,
    "c" : 1
}

# %%
dic2 = {
    "b" : 1,
    "a" : 1,
    #"c" : 1,
    #"e" : 0
}

# %%
dic1 == dic2
# Out:
# False
